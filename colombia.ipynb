# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import fetchdata.colombia as fcolombia

# %%
covid = fcolombia.CovidColombia()
covid.fetch_data()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Read local data.
# Data Loaded.
# Download remote data.
# Read local data.
# Data Loaded.
# Local data is already up to date.

# %%
covid.plot_cases()

# %%
covid.plot_cases_per_state()

# %%
covid.plot_cases_for_state('ANTIOQUIA')

# %%
covid.plot_cases_largest_for_state('ANTIOQUIA', 20)

# %%
covid.plot_incidence()

# %%
covid.plot_cases_for_municipality('JARDIN')

# %%
covid.plot_cases_for_state('QUINDIO')

# %%
covid.plot_cases_for_municipality('SALENTO')
