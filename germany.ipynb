# %%
import fetchdata.germany as fgermany

# %%
#fgermany.fetch_data()
#data = fgermany.read_data()
covid = fgermany.CovidGermany()
covid.fetch_data()
# Out:
# Local data up to date.
# Read local data.

# %%
covid.plot_cases()

# %%
print(covid.last_date)
# Out:
# 2021-05-03T00:00:00.000000000
