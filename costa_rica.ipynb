# %%
import fetchdata.costa_rica as fcosta

# %%
covid = fcosta.CovidCR()
covid.fetch_data()
# Out:
# Read csv file
# Local data already up to date.

# %%
covid.plot_cases()

# %%
covid.plot_cases_per_state()

# %%
covid.plot_incidence()

# %%
covid.plot_cases_for_municipality('Talamanca')
